# %%
import pandas as pd
# Out:
# /var/folders/hh/6z7j1dq90fgg9yk98vjm32140000gn/T/ipykernel_49912/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
image_data_df = pd.read_csv("/Users/puneetgautam/Downloads/abc.csv")

# %%
    image_data_df = image_data_df.dropna()

# %%
image_data_df
# Out:
#        depth   col1   col2   col3   col4   col5   col6   col7   col8   col9  \
# 0     9000.1  224.0  224.0  224.0  224.0  224.0  224.0  224.0  224.0  224.0
# 1     9000.2  224.0  224.0  224.0  224.0  224.0  224.0  224.0  224.0  224.0
# 2     9000.3  224.0  224.0  224.0  224.0  224.0  224.0  224.0  224.0  224.0
# 3     9000.4  224.0  224.0  224.0  224.0  224.0  224.0  224.0  224.0  224.0
# 4     9000.5  224.0  224.0  224.0  224.0  224.0  224.0  224.0  224.0  224.0
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 5455  9545.6  203.0  202.0  199.0  195.0  193.0  190.0  188.0  186.0  181.0
# 5456  9545.7  209.0  206.0  199.0  194.0  195.0  195.0  189.0  187.0  198.0
# 5457  9545.8  184.0  188.0  198.0  205.0  205.0  203.0  197.0  193.0  201.0
# 5458  9545.9  147.0  161.0  195.0  218.0  218.0  212.0  207.0  201.0  197.0
# 5459  9546.0  131.0  149.0  194.0  225.0  223.0  216.0  211.0  204.0  196.0
#
# ...

# %%
from PIL import Image

image_data_df.iloc[:, 1:] = image_data_df.iloc[:, 1:].apply(
            lambda row: list(Image.fromarray(row.values.reshape(1, -1), 'L').resize((150, 1)).getdata()), axis=1
        )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 from PIL import Image
# ----> 3 image_data_df.iloc[:, 1:] = image_data_df.iloc[:, 1:].apply(
#       4             lambda row: list(Image.fromarray(row.values.reshape(1, -1), 'L').resize((150, 1)).getdata()), axis=1
#       5         )
#
# File ~/miniconda3/envs/aiq-python/lib/python3.10/site-packages/pandas/core/indexing.py:912, in _LocationIndexer.__setitem__(self, key, value)
#     909 self._has_valid_setitem_indexer(key)
#     911 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 912 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~/miniconda3/envs/aiq-python/lib/python3.10/site-packages/pandas/core/indexing.py:1946, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1943 # align and set the values
#    1944 if take_split_path:
# ...
